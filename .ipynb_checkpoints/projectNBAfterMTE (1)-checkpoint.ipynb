# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import itertools
# %matplotlib inline

# %%
dataset=pd.read_csv('Concrete_Data.csv')

# %%
dataset=dataset.rename(columns={'Cement (component 1)(kg in a m^3 mixture)':'cement',
            'Blast Furnace Slag (component 2)(kg in a m^3 mixture)':'slag',
            'Fly Ash (component 3)(kg in a m^3 mixture)':'fly ash',
            'Water  (component 4)(kg in a m^3 mixture)':'water',
            'Superplasticizer (component 5)(kg in a m^3 mixture)':'SP',
            'Coarse Aggregate  (component 6)(kg in a m^3 mixture)':'CA',
            'Fine Aggregate (component 7)(kg in a m^3 mixture)':'FA',
            'Age (day)':'age',
            'Concrete compressive strength(MPa, megapascals)':'strength'})

# %%
dataset.shape
# Out:
# (1030, 9)

# %% [markdown]
# ## checking null values in dataframe

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [cement, slag, fly ash, water, SP, CA, FA, age, strength]
# Index: []

# %%
dataset.isnull().sum()
# Out:
# cement      0
# slag        0
# fly ash     0
# water       0
# SP          0
# CA          0
# FA          0
# age         0
# strength    0
# dtype: int64

# %%
dataset.describe()
# Out:
#             cement         slag      fly ash        water           SP  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  1030.000000
# mean    281.167864    73.895825    54.188350   181.567282     6.204660
# std     104.506364    86.279342    63.997004    21.354219     5.973841
# min     102.000000     0.000000     0.000000   121.800000     0.000000
# 25%     192.375000     0.000000     0.000000   164.900000     0.000000
# 50%     272.900000    22.000000     0.000000   185.000000     6.400000
# 75%     350.000000   142.950000   118.300000   192.000000    10.200000
# max     540.000000   359.400000   200.100000   247.000000    32.200000
#
#                 CA           FA          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# 25%     932.000000   730.950000     7.000000    23.710000
# 50%     968.000000   779.500000    28.000000    34.445000
# 75%    1029.400000   824.000000    56.000000    46.135000
# max    1145.000000   992.600000   365.000000    82.600000

# %% [markdown]
# ## checking correlation between features

# %%
sbn.pairplot(dataset, diag_kind='kde')

# %%
plt.figure(figsize=(25,25))
sbn.heatmap(dataset.corr(),cmap='coolwarm',annot=True,linewidth=2)
plt.title('correlation b/w features')
# Out:
# Text(0.5, 1.0, 'correlation b/w features')

# %%
fig,allDistPlots=plt.subplots(3,3,figsize=(16,16))
i=0
j=0
for feature in dataset.columns:
    sbn.distplot(dataset[feature],ax=allDistPlots[i][j])
    j+=1
    if(j>2):
        i+=1
        j=0
# Out:
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tinkal Kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## checking outliers in data

# %%
sbn.boxplot(data=dataset)
# Out:
# <AxesSubplot:>

# %%
fig,allBoxPlots=plt.subplots(3,3,figsize=(16,16))
i=0
j=0
for feature in dataset.columns:
    dataset.boxplot(feature,ax=allBoxPlots[i][j])
    plt.ylabel(feature)
    j+=1
    if(j>2):
        i+=1
        j=0

# %%
for feature in dataset.columns:
    print("Outliers in ",feature," are: ",
          dataset[(((dataset[feature]-dataset[feature].mean())/dataset[feature].std()).abs()>3)][feature].count())
# Out:
# Outliers in  cement  are:  0
# Outliers in  slag  are:  4
# Outliers in  fly ash  are:  0
# Outliers in  water  are:  2
# Outliers in  SP  are:  10
# Outliers in  CA  are:  0
# Outliers in  FA  are:  0
# Outliers in  age  are:  33
# Outliers in  strength  are:  0

# %% [markdown]
# ### Removing outliers

# %% [markdown]
# ##### Here we are not considering outliers in "age"

# %%
# (x-mew)/(sigma)<=+3
left_lim_slag=-3*dataset["slag"].std()+dataset["slag"].mean()
print("left_lim_slag is:",left_lim_slag)

left_lim_water=-3*dataset["water"].std()+dataset["water"].mean()
print("left_lim_water is:",left_lim_water)

left_lim_SP=-3*dataset["SP"].std()+dataset["SP"].mean()
print("left_lim_SP is:",left_lim_SP)
left_lim_Age=-3*dataset['age'].std()+dataset['age'].mean()
print("left_lim_Age is:",left_lim_Age)
# Out:
# left_lim_slag is: -182.0093628273342
# left_lim_water is: 119.09405503004469
# left_lim_SP is: -10.528930952231704
# left_lim_Age is: -144.73754511502398

# %%
# (x-mew)/(sigma)>=-3
right_lim_slag=3*dataset["slag"].std()+dataset["slag"].mean()
print("right_lim_slag is:",right_lim_slag)

right_lim_water=3*dataset["water"].std()+dataset["water"].mean()
print("right_lim_water is",right_lim_water)

right_lim_SP=3*dataset["SP"].std()+dataset["SP"].mean()
print("right_lim_SP is",right_lim_SP)
right_lim_Age=3*dataset['age'].std()+dataset['age'].mean()
print("left_lim_Age is:",right_lim_Age)
# Out:
# right_lim_slag is: 327.84762712713695
# right_lim_water is 244.57379506857455
# right_lim_SP is 22.514729768799754
# left_lim_Age is: 236.52452736354468

# %%
dataset.describe()
# Out:
#             cement         slag      fly ash        water           SP  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean    279.282347    72.919132    54.902860   181.833925     5.992899
# std     102.930632    84.976165    64.176615    20.913290     5.507277
# min     102.000000     0.000000     0.000000   121.800000     0.000000
# 25%     191.025000     0.000000     0.000000   164.900000     0.000000
# 50%     272.800000    22.000000     0.000000   185.000000     6.400000
# 75%     349.750000   142.950000   118.300000   192.000000    10.100000
# max     540.000000   316.100000   200.100000   237.000000    23.400000
#
#                 CA           FA          age     strength
# count  1014.000000  1014.000000  1014.000000  1014.000000
# mean    974.442604   773.224162    45.893491    35.645128
# std      77.225729    79.881805    63.543679    16.666211
# min     801.000000   594.000000     1.000000     2.330000
# 25%     932.000000   733.250000     7.000000    23.550000
# 50%     968.000000   779.300000    28.000000    34.080000
# 75%    1030.000000   822.150000    56.000000    45.807500
# max    1145.000000   992.600000   365.000000    82.600000

# %%
dataset=dataset[(dataset.slag>=left_lim_slag) & (dataset.slag<=right_lim_slag)]
dataset=dataset[(dataset.water>=left_lim_water) & (dataset.water<=right_lim_water)]
dataset=dataset[(dataset.SP>=left_lim_SP) & (dataset.SP<=right_lim_SP)]
dataset=dataset[(dataset.age>=left_lim_Age) & (dataset.age<=right_lim_Age)]

# %%
dataset.shape
# Out:
# (976, 9)

# %%
dataset.describe()
# Out:
#            cement        slag     fly ash       water          SP  \
# count  976.000000  976.000000  976.000000  976.000000  976.000000
# mean   276.989857   73.000205   57.040471  181.037500    6.106352
# std    102.619158   85.403048   64.475605   19.813268    5.360023
# min    102.000000    0.000000    0.000000  121.800000    0.000000
# 25%    190.300000    0.000000    0.000000  164.900000    0.000000
# 50%    263.250000   20.000000    0.000000  184.200000    6.700000
# 75%    349.000000  144.700000  118.300000  192.000000   10.200000
# max    540.000000  316.100000  200.100000  237.000000   22.100000
#
#                 CA          FA         age    strength
# count   976.000000  976.000000  976.000000  976.000000
# mean    975.357480  774.894365   36.445697   35.214682
# std      77.465443   76.281794   36.890289   16.715592
# min     801.000000  594.000000    1.000000    2.330000
# 25%     932.000000  738.500000    7.000000   23.125000
# 50%     968.000000  780.000000   28.000000   33.675000
# 75%    1038.500000  822.000000   28.000000   45.080000
# max    1145.000000  945.000000  180.000000   82.600000

# %% [markdown]
# # Classifying data into dependent and independent features

# %%
x=dataset.iloc[:,:-1]
xc=x
y=dataset.iloc[:,-1]
print(x)
# Out:
#       cement   slag  fly ash  water    SP      CA     FA  age
# 0      540.0    0.0      0.0  162.0   2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0   2.5  1055.0  676.0   28
# 5      266.0  114.0      0.0  228.0   0.0   932.0  670.0   90
# 7      380.0   95.0      0.0  228.0   0.0   932.0  594.0   28
# 8      266.0  114.0      0.0  228.0   0.0   932.0  670.0   28
# ...      ...    ...      ...    ...   ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6   8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0  10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7   6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6  11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6   8.6   864.5  761.5   28
#
# [976 rows x 8 columns]

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# # Splitting train test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# # Building different Models

# %% [markdown]
# ## 1. Multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model_lr.coef_
# Out:
# array([12.43862154,  8.5441908 ,  4.95788395, -3.36744808,  2.00724883,
#         0.77645472,  1.01663514,  8.2445429 ])

# %%
model_lr.intercept_
# Out:
# 35.21806936143836

# %%
training_score_lr=model_lr.score(x_train,y_train)*100
training_score_lr
# Out:
# 72.01065454414525

# %%
y_pred_lr = model_lr.predict(x_test)

# %%
MSE_lr=mean_squared_error(y_test,y_pred_lr)
MSE_lr
# Out:
# 91.34435696928186

# %%
acc_lr = r2_score(y_test,y_pred_lr)*100
acc_lr
# Out:
# 64.0612729932137

# %% [markdown]
# ##### Maintaing a result dataframe of various Algorithm and their Accuracy

# %%
Results=pd.DataFrame({'Algorithm':'Multiple linear regression','Accuracy':acc_lr},index={1})
Results
# Out:
#                     Algorithm   Accuracy
# 1  Multiple linear regression  64.061273

# %% [markdown]
# ## 2. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf=RandomForestRegressor()

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
training_score_rf=model_rf.score(x_train,y_train)*100
training_score_rf
# Out:
# 98.18682236826322

# %%
testing_score_rf=model_rf.score(x_test,y_test)*100
testing_score_rf
# Out:
# 89.38845334067551

# %%
y_pred_rf=model_rf.predict(x_test)

# %%
acc_rf=r2_score(y_test,y_pred_rf)*100 # r2 score=1-(SSr/SSm)
acc_rf
# Out:
# 89.38845334067551

# %%
MSE_rf=mean_squared_error(y_test,y_pred_rf)
MSE_rf
# Out:
# 27.244429964889612

# %%
Results.loc[2]=['Random Forest',acc_rf]
Results
# Out:
#                     Algorithm   Accuracy
# 1  Multiple linear regression  64.061273
# 2               Random Forest  89.388453

# %% [markdown]
# ## 3. KFold cross validation on random forest

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
kfold = KFold(n_splits=30,shuffle=True,random_state=3)
res_kfold_rf = cross_val_score(model_rf, x, y, cv=kfold)
res_kfold_rf
# Out:
# array([0.89729787, 0.92161066, 0.95940465, 0.76393561, 0.97146021,
#        0.92175758, 0.93240023, 0.92809194, 0.93884374, 0.94995389,
#        0.88548943, 0.90738508, 0.95113338, 0.89444093, 0.96256401,
#        0.92231124, 0.92403668, 0.86456599, 0.90788641, 0.91789859,
#        0.90482263, 0.90349525, 0.89790952, 0.77066627, 0.93634694,
#        0.86642589, 0.92579496, 0.93088523, 0.90715313, 0.9557893 ])

# %%
acc_kfold_rf = res_kfold_rf.mean()*100
acc_kfold_rf
# Out:
# 91.07252410921741

# %%
Results.loc[3]=['Random forest KFold',acc_kfold_rf]
Results
# Out:
#                     Algorithm   Accuracy
# 1  Multiple linear regression  64.061273
# 2               Random Forest  89.388453
# 3         Random forest KFold  91.072524

# %% [markdown]
# ## 4. KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

diff_k=[]
for i in range(1,100,2):
  knn = KNeighborsRegressor(n_neighbors=i)
  knn.fit(x_train, y_train)
  pred_i = knn.predict(x_test)
  diff_k.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1,100,2),diff_k,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('Different K Values')
plt.xlabel('K Values')
plt.ylabel('Mean errors')
# Out:
# Text(0, 0.5, 'Mean errors')

# %% [raw]
# selecting k = 3 from above plot

# %%
model_knn = KNeighborsRegressor(n_neighbors=3)
model_knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred_knn = model_knn.predict(x_test)

# %%
training_score_knn=model_knn.score(x_train, y_train)*100
training_score_knn
# Out:
# 88.05447083642451

# %%
testing_score_knn=model_knn.score(x_test,y_test)*100
testing_score_knn
# Out:
# 74.12732064238554

# %%
acc_knn=r2_score(y_test, y_pred_knn)*100
acc_knn
# Out:
# 74.12732064238554

# %%
Results.loc[4]=['KNN Regressor',acc_knn]
Results
# Out:
#                     Algorithm   Accuracy
# 1  Multiple linear regression  64.061273
# 2               Random Forest  89.388453
# 3         Random forest KFold  91.072524
# 4               KNN Regressor  74.127321

# %% [markdown]
# ## 5. Support Vector Machine

# %%
from sklearn.svm import SVR
model_svm = SVR(kernel='rbf')
model_svm.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred_svm = model_svm.predict(x_test)

# %%
model_svm.score(x_train, y_train)
# Out:
# 0.7010069374414576

# %%
acc_svm=r2_score(y_test, y_pred_svm)*100
acc_svm
# Out:
# 70.93382275167171

# %%
MSE_svm=mean_squared_error(y_test, y_pred_svm)
MSE_svm
# Out:
# 74.62544865628082

# %%
Results.loc[5]=['Support Vector Machine',acc_svm]
Results
# Out:
#                     Algorithm   Accuracy
# 1  Multiple linear regression  64.061273
# 2               Random Forest  89.388453
# 3         Random forest KFold  91.072524
# 4               KNN Regressor  74.127321
# 5      Support Vector Machine  70.933823

# %% [markdown]
# ## 6. KFold Support Vector Machine

# %%
k=20
kfold = KFold(n_splits=20,shuffle=True,random_state=3)
res_kfold_svm = cross_val_score(model_svm, x, y, cv=kfold)
res_kfold_svm
# Out:
# array([0.2537732 , 0.21609856, 0.17351901, 0.25164286, 0.17730687,
#        0.22725673, 0.2164395 , 0.28737815, 0.23700217, 0.30586013,
#        0.11565731, 0.20092722, 0.16430067, 0.30899572, 0.20604446,
#        0.27969135, 0.27922328, 0.20818738, 0.2322695 , 0.16065488])

# %%
acc_kfold_svm = res_kfold_svm.mean()*100
acc_kfold_svm
# Out:
# 22.511144751389097

# %%
Results.loc[6]=['KFold Support Vector Machine',acc_kfold_svm]
Results
# Out:
#                           Algorithm   Accuracy
# 1        Multiple linear regression  64.061273
# 2                     Random Forest  89.388453
# 3               Random forest KFold  91.072524
# 4                     KNN Regressor  74.127321
# 5            Support Vector Machine  70.933823
# 6      KFold Support Vector Machine  22.511145
# 7           Decision Tree Regressor  77.330354
# 8     KFold Decision Tree Regressor  84.730189
# 9         Decision Tree Regressor 2  86.163451
# 10  Pruning Decision Tree Regressor  51.242092

# %% [markdown]
# ## 7. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
model_dec=DecisionTreeRegressor()
model_dec.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print('Feature importance: \n',pd.DataFrame(model_dec.feature_importances_,columns=['Importance'],index=xc.columns))
# Out:
# Feature importance:
#           Importance
# cement     0.352388
# slag       0.073357
# fly ash    0.008321
# water      0.071057
# SP         0.091220
# CA         0.032955
# FA         0.035638
# age        0.335063

# %%
y_pred_dt=model_dec.predict(x_test)
y_pred_dt
# Out:
# array([53.52 , 37.43 , 61.24 , 14.2  , 29.41 ,  4.83 , 24.66 , 15.87 ,
#        43.57 ,  7.4  , 47.13 , 57.92 , 26.05 , 41.54 , 33.8  , 43.57 ,
#        27.68 ,  9.74 , 76.24 , 45.08 , 42.64 , 50.725, 44.28 , 38.8  ,
#        24.66 , 27.74 , 33.66 , 14.94 , 35.86 , 35.76 , 43.58 , 24.5  ,
#        31.42 , 10.54 , 43.57 , 27.83 , 37.4  , 45.37 , 44.14 , 42.42 ,
#        38.02 , 42.42 , 41.84 , 26.06 , 12.18 , 32.01 ,  6.81 , 38.02 ,
#        25.89 , 47.82 , 17.24 , 41.1  , 71.7  , 28.24 , 40.76 , 31.35 ,
#        40.66 , 25.22 , 47.4  , 40.66 , 43.5  , 36.44 , 38.77 , 44.61 ,
#        13.29 , 77.3  , 12.47 , 33.69 , 37.91 , 54.1  , 22.53 , 40.66 ,
#        39.42 , 17.95 , 38.46 , 45.94 , 42.64 , 27.23 , 29.23 , 47.82 ,
#        42.33 , 13.29 , 38.77 , 31.88 , 15.42 , 23.52 , 11.65 , 26.31 ,
#        29.87 , 25.2  , 24.1  , 26.92 , 31.45 , 44.09 , 35.87 , 14.2  ,
#        41.37 , 32.77 , 32.05 , 31.81 , 36.8  , 34.74 , 33.36 , 28.24 ,
#        75.5  , 65.2  , 33.56 , 49.2  , 38.07 , 38.63 , 35.23 , 39.64 ,
#        23.25 , 27.77 , 48.59 , 10.76 , 65.2  , 65.91 , 39.78 , 29.65 ,
#        28.24 , 28.94 , 26.86 , 19.42 , 53.39 , 40.86 , 32.05 , 56.34 ,
#        18.   , 29.65 , 71.7  , 69.84 , 24.07 , 77.3  , 40.86 ,  9.85 ,
#        30.19 , 34.77 , 39.32 ,  9.87 , 24.43 , 43.89 , 49.9  , 21.06 ,
#        36.94 , 59.49 , 55.02 , 47.13 , 38.46 , 13.29 , 10.34 , 24.34 ,
#        79.3  , 32.72 , 51.02 , 24.5  , 47.4  , 48.79 , 15.87 , 48.59 ,
#        43.57 , 15.87 , 37.81 , 18.28 , 60.95 , 75.5  , 35.86 , 50.53 ,
#        55.02 , 39.06 , 31.88 , 35.87 , 36.44 , 39.42 , 47.82 , 38.46 ,
#        15.69 , 55.25 , 34.77 , 51.96 , 54.1  ,  9.45 , 45.94 , 31.81 ,
#        59.59 , 26.06 , 16.88 , 10.76 , 50.46 , 38.8  , 33.54 , 15.42 ,
#        39.3  , 31.81 , 71.7  , 45.3  , 77.3  , 19.69 , 47.13 , 51.72 ,
#        36.44 , 38.63 , 31.35 , 13.18 , 27.83 , 23.52 , 37.36 , 15.36 ,
#        33.05 , 22.75 ,  7.72 , 13.2  , 31.81 , 55.94 , 50.725, 38.02 ,
#        15.36 , 19.42 , 14.2  , 27.77 , 43.57 , 52.96 , 15.09 , 46.24 ,
#        55.45 , 41.05 , 18.13 , 54.9  , 24.4  , 61.09 , 37.36 , 22.5  ,
#        38.63 , 32.96 , 13.29 , 37.92 , 55.25 , 20.08 , 30.44 , 10.38 ,
#        25.1  , 19.69 , 46.24 , 11.41 , 33.31 ,  4.9  , 27.74 , 17.2  ,
#        30.85 , 72.1  , 45.9  , 31.64 , 44.52 , 32.72 , 15.87 , 24.85 ,
#        43.57 , 47.81 , 43.57 , 10.34 , 25.1  , 23.79 , 35.76 , 47.22 ,
#        55.2  , 33.4  , 35.76 , 23.52 , 24.07 , 55.02 , 52.82 , 67.8  ,
#        66.42 , 24.66 , 10.22 , 33.72 , 19.99 , 32.72 ,  9.56 , 24.05 ,
#        72.3  , 26.92 , 10.38 , 33.8  , 35.3  , 29.22 , 38.8  , 40.93 ,
#        33.8  , 71.7  , 18.13 , 40.39 , 25.46 ])

# %%
model_dec.score(x_train,y_train)
# Out:
# 0.9951534259075443

# %%
model_dec.score(x_test,y_test)
# Out:
# 0.7582207257588265

# %%
acc_dt=r2_score(y_pred_dt,y_test)*100
acc_dt
# Out:
# 75.82200129899374

# %%
Results.loc[7]=['Decision Tree Regressor',acc_dt]
Results
# Out:
#                           Algorithm   Accuracy
# 1        Multiple linear regression  64.061273
# 2                     Random Forest  89.388453
# 3               Random forest KFold  91.072524
# 4                     KNN Regressor  74.127321
# 5            Support Vector Machine  70.933823
# 6      KFold Support Vector Machine  22.511145
# 7           Decision Tree Regressor  75.822001
# 8     KFold Decision Tree Regressor  84.730189
# 9         Decision Tree Regressor 2  86.163451
# 10  Pruning Decision Tree Regressor  51.242092

# %% [markdown]
# ## 8. KFold Decision Tree Regressor

# %%
k=30
kfold_dt=KFold(n_splits=k,shuffle=True,random_state=5)
res_kfold_dt=cross_val_score(model_dec,x,y,cv=kfold_dt)
res_kfold_dt
# Out:
# array([0.91034662, 0.72339515, 0.86448773, 0.70144901, 0.92905581,
#        0.86893457, 0.90949751, 0.86334018, 0.67264038, 0.90350039,
#        0.79689686, 0.89707621, 0.89462996, 0.80860914, 0.87585688,
#        0.84747895, 0.8790896 , 0.93692607, 0.73766861, 0.86284847,
#        0.81127928, 0.93147009, 0.90816178, 0.81530715, 0.90038984,
#        0.9237372 , 0.90512824, 0.87611939, 0.91989623, 0.70687832])

# %%
acc_kfold_dt=res_kfold_dt.mean()*100
acc_kfold_dt
# Out:
# 85.27365210255343

# %%
Results.loc[8]=['KFold Decision Tree Regressor',acc_kfold_dt]
Results
# Out:
#                           Algorithm   Accuracy
# 1        Multiple linear regression  64.061273
# 2                     Random Forest  89.388453
# 3               Random forest KFold  91.072524
# 4                     KNN Regressor  74.127321
# 5            Support Vector Machine  70.933823
# 6      KFold Support Vector Machine  22.511145
# 7           Decision Tree Regressor  75.822001
# 8     KFold Decision Tree Regressor  85.273652
# 9         Decision Tree Regressor 2  86.163451
# 10  Pruning Decision Tree Regressor  51.242092

# %% [markdown]
# ## Feature Selection

# %%
dataset2=dataset.copy()

# %%
X=dataset2.iloc[:,:-1]
X=X.drop(['fly ash','CA','FA'],axis=1)
Y=dataset2.iloc[:,-1]
xc=X

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=1)

# %%
new_dec_model=DecisionTreeRegressor()
new_dec_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print('Feature importance: \n',pd.DataFrame(new_dec_model.feature_importances_,columns=['Importance'],index=xc.columns))
# Out:
# Feature importance:
#          Importance
# cement    0.375461
# slag      0.109514
# water     0.123966
# SP        0.055130
# age       0.335928

# %%
y_pred_NewDt=new_dec_model.predict(x_test)

# %%
new_model_acc=r2_score(y_pred_NewDt,y_test)*100
new_model_acc
# Out:
# 85.66053618206305

# %%
Results.loc[9]=['Decision Tree Regressor 2',new_model_acc]
Results
# Out:
#                           Algorithm   Accuracy
# 1        Multiple linear regression  64.061273
# 2                     Random Forest  89.388453
# 3               Random forest KFold  91.072524
# 4                     KNN Regressor  74.127321
# 5            Support Vector Machine  70.933823
# 6      KFold Support Vector Machine  22.511145
# 7           Decision Tree Regressor  75.822001
# 8     KFold Decision Tree Regressor  85.273652
# 9         Decision Tree Regressor 2  85.660536
# 10  Pruning Decision Tree Regressor  51.242092

# %% [markdown]
# ## Pruning Decision Tree

# %%
X=dataset.drop(['strength'],axis=1)
xc=X
Y=dataset['strength']

# %%
from scipy import stats
Xscaled=stats.zscore(X)
Xscaled_df=pd.DataFrame(Xscaled,columns=dataset.columns)

# %%
x_train,x_test,y_train,y_test=train_test_split(Xscaled,Y,test_size=0.3,random_state=5)

# %%
dt_prun_model=tree.DecisionTreeRegressor(max_depth=4,random_state=1,min_samples_leaf=5)
dt_prun_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_leaf=5, random_state=1)

# %%
print('Feature importance: \n',pd.DataFrame(dt_prun_model.feature_importances_,columns=['Importance'],index=xc.columns))
# Out:
# Feature importance:
#           Importance
# cement     0.421864
# slag       0.031175
# fly ash    0.000000
# water      0.070190
# SP         0.086034
# CA         0.000000
# FA         0.000000
# age        0.390738

# %%
y_pred_PrunDt=dt_prun_model.predict(x_test)

# %%
prun_dt_acc=r2_score(y_pred_PrunDt,y_test)*100
prun_dt_acc
# Out:
# 51.242091785808505

# %%
Results.loc[10]=['Pruning Decision Tree Regressor',prun_dt_acc]
Results
# Out:
#                           Algorithm   Accuracy
# 1        Multiple linear regression  64.061273
# 2                     Random Forest  89.388453
# 3               Random forest KFold  91.072524
# 4                     KNN Regressor  74.127321
# 5            Support Vector Machine  70.933823
# 6      KFold Support Vector Machine  22.511145
# 7           Decision Tree Regressor  75.822001
# 8     KFold Decision Tree Regressor  85.273652
# 9         Decision Tree Regressor 2  85.660536
# 10  Pruning Decision Tree Regressor  51.242092

# %% [markdown]
# ## Plotting Decision Tree

# %%
Xscaled_df=Xscaled_df.drop('strength',axis=1)

# %%
feature_cols=Xscaled_df.columns
feature_cols
# Out:
# Index(['cement', 'slag', 'fly ash', 'water', 'SP', 'CA', 'FA', 'age'], dtype='object')

# %%
from sklearn import tree
from matplotlib import pyplot as plt
fig=plt.figure(figsize=(20,18))
_=tree.plot_tree(dt_prun_model,feature_names=feature_cols,class_names={0:'Malignant',1:'Benign'},filled=True,fontsize=14)

# %%
fig=plt.figure(figsize=(20,10))

# %%
plt.bar(Results['Algorithm'],Results['Accuracy'])
plt.xticks(rotation=90)
plt.ylabel('Accuracy')
plt.show()
